# %% [markdown]
# 📋 Estructura de la Clase
#
# ---
#
# | Bloque | Tema | Enfoque Práctico (Fútbol) |
# |---|---|---|
# | Bloque 1 | Intro al Aprendizaje No Supervisado | Setup y entendimiento de los datos sin etiquetas. |
# | Bloque 2 | Reglas de Asociación ($Support, Confidence, Lift$) | ¿Qué estilos de juego suelen ocurrir juntos en los equipos? |
# | Bloque 3 | K-Means y Selección de $K$ (Codo / Silhouette) | Agrupar equipos por su perfil de Ataque vs. Posesión. |
# | Bloque 4 | Clustering Jerárquico y DBSCAN | Dendrogramas de similitud y detección de "equipos raros". |
# | Bloque 5 | Reducción de Dimensionalidad (PCA) | Resumir el rendimiento Físico y de Movimiento en 2 ejes. |
# | Bloque 6 | Panorama de Métodos y Cierre | Resumen de cuándo usar qué. |

# %% [markdown]
# 🛠️ Código de Inicialización (Pre-clase)
# -
#
# Para optimizar el tiempo, se asume que ejecutas esto al principio para unificar el dataset de las hojas de Data Set Fifa.xlsx de forma limpia:

# %%
# === CÓDIGO DE INICIO DEFINITIVO PARA 48 EQUIPOS EXACTOS ===
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

archivo_excel = 'Data-Set-Fifa.xlsx'
xls = pd.ExcelFile(archivo_excel)

def limpiar_nombre_equipo(nombre):
    if pd.isna(nombre): return nombre
    s = str(nombre).strip()
    s = s.replace('Espa帽a', 'España').replace('EspaÃ±a', 'España')
    s = s.replace('Uzbekist谩n', 'Uzbekistán').replace('UzbekistÃ¡n', 'Uzbekistán')
    s = s.replace('Arabia Saud铆', 'Arabia Saudí').replace('Arabia SaudÃ\xad', 'Arabia Saudí')
    s = s.replace('Rep煤blica de Corea', 'República de Corea').replace('RepÃºblica de Corea', 'República de Corea')
    s = s.replace('Jap贸n', 'Japón').replace('JapÃ³n', 'Japón').replace('Jap籀n', 'Japón')
    s = s.replace('Sud谩frica', 'Sudáfrica').replace('SudÃ¡frica', 'Sudáfrica')
    s = s.replace('Hait穩', 'Haití')
    return s

def procesar_hoja_con_glosario(xls_file, nombre_hoja):
    df_raw = pd.read_excel(xls_file, nombre_hoja)
    indices_datos = df_raw[df_raw['Puesto'].notna()].index

    registros = []
    for idx in indices_datos:
        datos_fila = df_raw.iloc[idx].copy()
        nombre_real = df_raw.iloc[idx + 1]['Equipo']
        datos_fila['Equipo'] = limpiar_nombre_equipo(nombre_real)
        registros.append(datos_fila)

    df_limpio = pd.DataFrame(registros).reset_index(drop=True)
    cols_validas = [c for c in df_limpio.columns if 'Unnamed' not in str(c) and 'glosario' not in str(c).lower() and c != 'Puesto']
    return df_limpio[cols_validas]

# 1. Creamos la lista maestra basada estrictamente en la primera hoja (Ataque)
df_maestro = procesar_hoja_con_glosario(xls, 'Ataque')
lista_48_equipos = df_maestro['Equipo'].dropna().unique()

# 2. Inicializamos el DataFrame final con la estructura maestra
df_final = df_maestro.copy()

# 3. Cruzamos el resto de las hojas de forma relacional permisiva
for hoja in xls.sheet_names[1:]:
    df_hoja_limpia = procesar_hoja_con_glosario(xls, hoja)
    df_final = pd.merge(df_final, df_hoja_limpia, on='Equipo', how='outer')

# 4. Establecemos el índice provisorio
df_final = df_final.dropna(subset=['Equipo']).set_index('Equipo')

# 5. Forzamos al DataFrame a recortarse exactamente a los 48 oficiales de Ataque
# Rellenamos con la media de la columna si en alguna pestaña menor un país no cruzó por problemas de tipeo
df_final = df_final.reindex(lista_48_equipos)
df_final = df_final.fillna(df_final.mean(numeric_only=True))

# 6. Corregimos el nombre mal escrito que trae el Excel original ("Posecion del balon %")
df_final = df_final.rename(columns={'Posecion del balon %': 'Posesión del balón %'})

scaler = StandardScaler()

print(f"¡Proceso completado con éxito!")
print(f"Número de equipos fijados de forma perfecta en la matriz: {len(df_final)} (¡Exactamente 48!)")

# %% [markdown]
# 📐 Desarrollo de los
# Bloques 1. ¿Qué es el Aprendizaje No Supervisado?
# -
#
# Teoría Breve: A diferencia del aprendizaje supervisado, aquí no tenemos una variable objetivo ($y$) ni etiquetas.
#
# No buscamos predecir un número o una categoría preestablecida, sino encontrar la estructura oculta, patrones o relaciones subyacentes en las características ($X$).
#
#
# Analogía Práctica: "No sabemos quién ganó el torneo, ni qué táctica es la correcta; queremos que los datos nos digan de forma natural cómo se agrupan o se comportan los equipos de fútbol por sí solos".
#
# Bloque 2. Reglas de Asociación
# -
#
# Teoría Breve: Identifica relaciones condicionales del tipo “Si ocurre A, suele ocurrir B”.
#
#
#
# *   Soporte ($Support$): Qué tan frecuente es el conjunto de elementos en el total de los datos.
# *   Confianza ($Confidence$): Qué tan seguro es que ocurra B dado que ocurrió A.
#
# *  Elevación ($Lift$): Qué tanto más coocurren A y B respecto a si fueran independientes. Si $Lift > 1$, la regla es significativa.
#
#
# Práctica: Convertiremos variables continuas del dataset en "Categorías Binarias" (Alto/Bajo) para ver qué métricas de ataque se asocian.

# %%
import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning)
#-----------------------------------------------------------------
from mlxtend.frequent_patterns import apriori, association_rules

# 1. Crear transacciones usando tipos Booleanos (True/False) para evitar el Warning
features_rules = ['Goles', 'Asistencias', 'Remates', 'Posesión del balón %']
df_binario = df_final[features_rules].apply(lambda x: x > x.median()).astype(bool)

# 2. Aplicar Apriori
frequent_itemsets = apriori(df_binario, min_support=0.3, use_colnames=True)

# 3. Generar reglas de asociación
reglas = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7)

# Mostrar el top 3 ordenado por Lift
print(reglas[['antecedents', 'consequents', 'support', 'confidence', 'lift']].sort_values(by='lift', ascending=False).head(3))

# %% [markdown]
# Glosario de Métricas en el Output
# antecedents (Antecedente / Condición): El "Si ocurre esto...". Es el grupo de variables de origen.
#
# consequents (Consecuente / Resultado): El "...entonces pasará esto". Es el grupo de variables que se asocia al origen.
#
# support (Soporte): Qué tan frecuente es la regla completa. Un soporte de 0.3125 significa que el 31.25% de todos los equipos del torneo (exactamente 15 de los 48 equipos) cumplen con tener altas todas las variables involucradas en esa regla al mismo tiempo.
#
# confidence (Confianza): La certeza de la regla. Mide cuántas veces se cumple el consecuente dentro del grupo de equipos que ya tienen el antecedente.
#
# lift (Elevamiento / Fuerza): Mide la fuerza real de la regla.
#
# Si el lift es igual a 1, el antecedente y el consecuente son independientes.
#
# Como todos los valores acá son mayores a 2, significa que la relación no es casualidad; hay una fuerte dependencia estadística entre estas variables.
#
# Conclusión  El análisis demuestra cuantitativamente que en el fútbol moderno el éxito ofensivo es un ecosistema interconectado. No se puede aislar la posesión del gol, ni los remates de las asistencias; los equipos que superan la media en un par de estas métricas quedan prácticamente "condenados" por la estadística a destacar en las demás.

# %% [markdown]
# Bloque 3 K-Means y Elección de $K$
# -
#
# Teoría Breve: Divide los datos en $K$ grupos minimizando la varianza interna (distancia al centroide).
#
# Método del Codo (Inercia): Gráfico de la suma de cuadrados de las distancias.
#
#  Buscamos el punto de inflexión donde añadir más clusters ya no reduce drásticamente la inercia.
#
#  Escalado: ¡Crucial! K-Means usa distancia euclidiana, por lo que exige estandarizar los datos previamente.
#
#  Práctica:
#  -
#   Agruparemos los equipos según su perfil de Posesión del balón % y Efectividad en los remates %.

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# 1. Selección y Escalado de características
X_kmeans = df_final[['Posesión del balón %', 'Efectividad en los remates %']].dropna()
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_kmeans)

# 2. Método del Codo (Inercia)
inercias = []
for k in range(1, 8):
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(X_scaled)
    inercias.append(kmeans.inertia_)

plt.figure(figsize=(5,3))
plt.plot(range(1, 8), inercias, marker='o')
plt.title('Método del Codo')
plt.xlabel('Número de Clusters (k)')
plt.ylabel('Inercia')
plt.grid(True)
plt.show()



# Instanciamos el modelo definitivo con 3 clusters
kmeans_opt = KMeans(n_clusters=3, random_state=42, n_init=10)

# Calculamos los clusters y los guardamos en el DataFrame original (sin escalar)
X_kmeans['Cluster'] = kmeans_opt.fit_predict(X_scaled)

print("--- PERFIL PROMEDIO DE CADA CLUSTER TÁCTICO ---")
print(X_kmeans.groupby('Cluster').mean())



#--------- CLUSTER POR EQUIPO ---------

# Agrupamos por 'Cluster' y extraemos los nombres del índice usando una función lambda
equipos_por_cluster = X_kmeans.groupby('Cluster').apply(lambda df: list(df.index), include_groups=False)

print("--- EQUIPOS EN CADA CLUSTER TÁCTICO ---")

# Iteramos sobre cada grupo de forma independiente
for num_cluster, lista_paises in equipos_por_cluster.items():
    print(f"\n⚽ CLUSTER {num_cluster}: ({len(lista_paises)} equipos)")
    # Unimos la lista de países con comas para que quede estético en la consola
    print(", ".join(lista_paises))

# %% [markdown]
# 🟢 Cluster 0: "Los Contundentes / Efectividad Máxima"
# Posesión del balón %: ~49.72% (Equilibrada / Cerca del promedio general)
#
# Efectividad en los remates %: 19.44% (Extremadamente Alta)
#
# Interpretación: Este es el grupo de los equipos ultra-eficientes. No necesitan monopolizar la pelota ni desgastarse con posesiones eternas para dominar el marcador. Su juego suele ser más directo, vertical o de contraataque letal.
#
# 🔴 Cluster 1: "Bloque Bajo / Juego Reactivo"
# Posesión del balón %: 35.11% (Muy Baja)
#
# Efectividad en los remates %: 7.67% (Baja)
#
# Interpretación: Equipos con una propuesta claramente defensiva o reactiva. Ceden casi por completo el control de la pelota al rival (promedian apenas un 35% de tenencia) y se resguardan en su propio campo.
#
# 🔵 Cluster 2: "Posesión Inofensiva"
# Posesión del balón %: 54.33% (Alta / Control de juego)
#
# Efectividad en los remates %: 7.42% (La más baja del torneo)
#
# Interpretación:  control posicional que carece de profundidad. Domina los hilos del partido, esconde el balón y se asocia mucho en la mitad de la cancha (superan el 54% de posesión promedio), pero es un dominio inofensivo. Al pisar el área rival se les "apaga la luz".
#
# 💡 Conclusiones Técnicas
# Validación de Variables: La segmentación demuestra que la posesión alta no garantiza efectividad. De hecho, el Cluster 0 tiene menos posesión que el Cluster 2, pero casi triplica su efectividad de cara al arco.
#
# Utilidad del Algoritmo: K-Means demostró ser excelente para resumir la complejidad de un torneo de 48 equipos en solo 3 categorías conceptuales simples, permitiendo a un cuerpo técnico o analista de datos categorizar rivales y planificar estrategias específicas para contrarrestar cada estilo.

# %% [markdown]
# Bloque 4 Clustering Jerárquico y DBSCAN
# -
#
# Teoría Breve:
#
# Hierarchical Clustering:
#
# Crea un árbol de similitud (Dendrograma) conectando observaciones de abajo hacia arriba o viceversa. No requiere predefinir $K$ desde el inicio.
#
# DBSCAN: Se basa en densidades de puntos (parámetros eps y min_samples). Ideal para encontrar formas geométricas complejas y aislar valores atípicos (ruido / outliers) que se codifican como
#
# Práctica:
# -
# Usar un mapa de calor jerárquico y aplicar DBSCAN para encontrar equipos con comportamientos defensivos inusuales.

# %%
import scipy.cluster.hierarchy as sch
from sklearn.cluster import DBSCAN

# 1. Clustering Jerárquico (Dendrograma)
X_defensa = scaler.fit_transform(df_final[['Goles recibidos', 'Pérdidas de balon provocadas']].dropna())
plt.figure(figsize=(6, 3))
dendrograma = sch.dendrogram(sch.linkage(X_defensa, method='ward'))
plt.title('Dendrograma Defensivo')
plt.show()

# 2. DBSCAN para detectar anomalías tácticas
dbscan = DBSCAN(eps=0.5, min_samples=3)
clusters_db = dbscan.fit_predict(X_defensa)
print(f"Equipos catalogados como Outliers/Ruido (-1): {np.sum(clusters_db == -1)}")


# Guardamos el resultado del cluster en la tabla original
df_final['DBSCAN_Cluster'] = clusters_db

# Filtramos la tabla para quedarnos solo con las filas que valen -1
outliers = df_final[df_final['DBSCAN_Cluster'] == -1]

print(f"Cantidad de anomalías encontradas: {len(outliers)}\n")
print("--- LISTA DE EQUIPOS ANÓMALOS (OUTLIERS) ---")
print(outliers[['Goles recibidos', 'Pérdidas de balon provocadas']])

# %% [markdown]
# El dendrograma representa el mapa genético de las similitudes defensivas de los equipos:
#
# Eje Vertical (Distancia/Disimilitud): Muestra qué tan diferentes son los equipos o grupos entre sí antes de fusionarse. Cuanto más alta sea la línea horizontal que une dos ramas, mayor es la diferencia estadística en sus perfiles defensivos.
#
# Eje Horizontal (Índices de Equipos):selecciones identificadas por su número de índice.
#
# Estructura de Tres Grandes Ramas:
#  horizontal imaginario a una altura de $5.5$ (en el eje vertical), claramente  los datos tienden a dividirse de forma natural en 3 macro-clusters:
#
#  El grupo Naranja (extrema izquierda): Equipos con un comportamiento defensivo muy particular y alejado de la mayoría.
#
#  El grupo Verde (centro-izquierda): Un subgrupo pequeño pero muy cohesionado.
#
#  El grupo Rojo (derecha): El bloque mayoritario del torneo, que concentra a las selecciones con comportamientos defensivos más "estándar" o promedio.
#
#
#  DBSCAN identificó 11 equipos como outliers (Ruido: -1). Al observar sus datos, vemos que el algoritmo no se equivocó: estos equipos no son necesariamente "malos", sino que sus estadísticas se van a los extremos del torneo (zonas de muy baja densidad de datos)
#
#  Piensen como clasificar esos outlier en grupos por ejemplo 3 grupos....

# %% [markdown]
# Bloque 5 Teoría de PCA y Consideraciones Prácticas
# -
# Teoría Breve:
#
#  Principal Component Analysis reduce la cantidad de variables proyectando los datos en nuevas direcciones ortogonales (Componentes Principales) que maximizan la varianza explicada.
#
#  Consideración práctica:
#
#  Se debe evaluar la Varianza Explicada Acumulada para decidir con cuántos componentes quedarnos (regla general: > 70-80%).
#
#  Las variables originales pierden su interpretabilidad directa, se transforman en combinaciones lineales.
#
#  Práctica:
#
#  Simplificar todo el bloque de variables de rendimiento físico (Velocidad Media (Km/h), Esprints, Distancia recorrida (m)) a solo 2 dimensiones para poder graficarlo.

# %%
from sklearn.decomposition import PCA
import plotly.express as px

# Seleccionar bloque Físico
cols_fisico = ['Velocidad Media (Km/h)', 'Esprint a gran velocidad', 'Esprints', 'Distancia recorrida (m)']
X_fisico = scaler.fit_transform(df_final[cols_fisico].dropna())

# Aplicar PCA
pca = PCA(n_components=2)
componentes = pca.fit_transform(X_fisico)

# Ratio de varianza explicada
print(f"Varianza explicada por componente: {pca.explained_variance_ratio_}")
print(f"Varianza explicada acumulada: {np.sum(pca.explained_variance_ratio_):.2%}")


# 1. Creamos el DataFrame usando la matriz 'componentes' generada por el PCA
df_pca_plot = pd.DataFrame({
    'PC1_Intensidad': componentes[:, 0],
    'PC2_Velocidad': componentes[:, 1],
    'Equipo': df_final.index             # El índice que contiene los 48 nombres reales alineados
})

# 2. Crear el gráfico interactivo con Plotly
fig = px.scatter(
    df_pca_plot,
    x='PC1_Intensidad',
    y='PC2_Velocidad',
    hover_name='Equipo',
    title='Mapa Dinámico de Equipos según su Rendimiento Físico (PCA)',
    labels={
        'PC1_Intensidad': 'Componente Principal 1 (Intensidad de carrera)',
        'PC2_Velocidad': 'Componente Principal 2 (Velocidad pura)'
    },
    template='plotly_white'
)

# Personalizar el color de los puntos para mantener el estilo morado/magenta
fig.update_traces(marker=dict(size=10, color='purple', opacity=0.7))

# Activar las líneas de cuadrícula para que sea idéntico al tuyo
fig.update_xaxes(showgrid=True, gridwidth=1, gridcolor='LightGray')
fig.update_yaxes(showgrid=True, gridwidth=1, gridcolor='LightGray')

# 3. Renderizar el mapa interactivo
fig.show()
# Out:
# Varianza explicada por componente: [0.80598225 0.16686856]
# Varianza explicada acumulada: 97.29%
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# PC1 (80.60%): El primer componente principal captura por sí solo el 80.60% de la variabilidad física total del torneo. Esto significa que las variables originales (como la distancia recorrida y los esprints) se alinean fuertemente en un factor común: la Intensidad de carrera.
#
# PC2 (16.69%): El segundo componente absorbe el 16.69% de la varianza restante, concentrándose en rasgos independientes del volumen, principalmente la Velocidad pura.
#
# Varianza Acumulada (97.29%): Al comprimir las 4 dimensiones originales a solo 2, solo se perdió un 2.71% de información. Este mapa bidimensional es una representación casi perfecta y sumamente fiel de la realidad física de los 48 equipos.
#
#
# Cuadrante Derecho (PC1 Positivo, Alto Volumen Físico)
# Es la gran masa concentrada del torneo. Los equipos que se desplazan hacia la derecha (valores de 0 a 3 en PC1)
#
# Cuadrante Izquierdo Alto (PC1 Negativo, PC2 Positivo - "Velocidad sin Resistencia")
# Hacia la izquierda (valores de -2 a -5 en PC1), vemos puntos aislados que se elevan en el eje Y.
#
# Estos equipos registran valores bajos en distancia total recorrida (poca resistencia o un juego muy estático/posicional)
#
# Extremo Inferior Izquierdo / Central (Bajo Rendimiento Físico)
#
# Los puntos rezagados en el fondo (valores negativos en ambos componentes, como los que están cerca de PC1 = -1, PC2 = -2 o en el extremo izquierdo -5) representan el déficit físico del torneo.
#
# Son selecciones que corrieron menos metros en promedio

# %% [markdown]
# Bloque 6 Panorama de Métodos y Cierre
# Teoría Breve / Resumen:
# -
#
# *   Usa Reglas de Asociación cuando busques patrones lógicos de coocurrencia (canastas de compra, sinergias de eventos).
# *   Usa K-Means si necesitas grupos claros, circulares y sabes cuántos quieres aproximadamente.
#
# *  Usa Hierarchical si te interesa entender la taxonomía/árbol de relación o parentesco entre los datos.
#
# *  Usa DBSCAN si tus datos tienen formas complejas o necesitas aislar ruido/anomalías con precisión.
#
# *  Usa PCA antes de modelar o graficar para quitar la redundancia (correlación) y simplificar el problema.
